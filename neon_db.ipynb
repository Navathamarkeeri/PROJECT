# %% [markdown]
# <a href="https://colab.research.google.com/github/Navathamarkeeri/PROJECT/blob/python/neon_db.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_excel('/content/Length_of_Stay_Dataset.xlsx')

# %%
df.head()
# Out:
#    Patient ID  Age  Gender Admission Type Primary Diagnosis  \
# 0       74579   77  Female      Emergency            Stroke
# 1       70994   41    Male         Urgent          Fracture
# 2       58228   23   Other        Newborn      Heart Attack
# 3       44881   31  Female        Newborn      Heart Attack
# 4       84716   69   Other         Urgent          Fracture
#
#             Comorbidities  Previous Hospitalizations      BP  Heart rate  \
# 0            Hypertension                        0.0  126/76          75
# 1                     NaN                        7.0  167/99          69
# 2                 Obesity                        5.0  106/70          69
# 3  Chronic Kidney Disease                        8.0  115/99          97
# 4  Chronic Kidney Disease                        NaN  153/97          88
#
#   Surgical Procedures Severity of Illness Insurance Type Socioeconomic Status  \
# 0                 NaN                Mild       Medicare          Upper class
# ...

# %%
df.columns
# Out:
# Index(['Patient ID', 'Age', 'Gender', 'Admission Type', 'Primary Diagnosis',
#        'Comorbidities', 'Previous Hospitalizations', 'BP', 'Heart rate',
#        'Surgical Procedures', 'Severity of Illness', 'Insurance Type',
#        'Socioeconomic Status', 'Hospital Total Beds', 'Room Type',
#        'Discharge Destination', 'Length of Stay in days'],
#       dtype='object')

# %%
df.columns  = df.columns.str.replace(' ', '_')

# %%
df.columns
# Out:
# Index(['Patient_ID', 'Age', 'Gender', 'Admission_Type', 'Primary_Diagnosis',
#        'Comorbidities', 'Previous_Hospitalizations', 'BP', 'Heart_rate',
#        'Surgical_Procedures', 'Severity_of_Illness', 'Insurance_Type',
#        'Socioeconomic_Status', 'Hospital_Total_Beds', 'Room_Type',
#        'Discharge_Destination', 'Length_of_Stay_in_days'],
#       dtype='object')

# %%
import psycopg2
DATABASE_URL = "postgresql://neondb_owner:SvDHQYLxb6p0@ep-misty-dew-a5qjuccb.us-east-2.aws.neon.tech/dbname?sslmode=require"

# %%
create_table_query = """CREATE TABLE IF NOT EXISTS length_of_stay5(
  Patient_ID integer, Age integer, Gender text, Admission_Type text, Primary_Diagnosis text,
       Comorbidities text, Previous_Hospitalizations integer, BP text, Heart_rate text,
       Surgical_Procedures text, Severity_of_Illness text, Insurance_Type text,
       Socioeconomic_Status text, Hospital_Total_Beds integer,
       Room_Type text,Discharge_Destination text,Length_of_Stay_in_days integer);"""

# %%
try:
    conn = psycopg2.connect(DATABASE_URL)
    cursor = conn.cursor()

    cursor.execute(create_table_query)
    conn.commit()
    cursor.close()
    conn.close()

except Exception as e:
    print(e)

# %%
try:
    x= 1/0
except Exception as e:
  print(e)
# Out:
# division by zero

# %%
df
# Out:
#      Patient_ID  Age  Gender Admission_Type Primary_Diagnosis  \
# 0         74579   77  Female      Emergency            Stroke
# 1         70994   41    Male         Urgent          Fracture
# 2         58228   23   Other        Newborn      Heart Attack
# 3         44881   31  Female        Newborn      Heart Attack
# 4         84716   69   Other         Urgent          Fracture
# ..          ...  ...     ...            ...               ...
# 995       12035   35  Female       Elective          Diabetes
# 996       57742   28   Other      Emergency      Heart Attack
# 997       89928   98   Other        Newborn         Pneumonia
# 998       99495    7    Male      Emergency         Pneumonia
# 999       67395    8    Male       Elective         Pneumonia
#
#               Comorbidities  Previous_Hospitalizations      BP  Heart_rate  \
# 0              Hypertension                        0.0  126/76          75
# ...

# %%
df.isnull().sum()
# Out:
# Patient_ID                     0
# Age                            0
# Gender                         0
# Admission_Type                 0
# Primary_Diagnosis              0
# Comorbidities                207
# Previous_Hospitalizations      2
# BP                             0
# Heart_rate                     0
# Surgical_Procedures          225
# Severity_of_Illness            0
# Insurance_Type                 0
# Socioeconomic_Status           0
# Hospital_Total_Beds            0
# Room_Type                      0
# Discharge_Destination          0
# Length_of_Stay_in_days         0
# dtype: int64

# %%
l1 = [1,2,3,4,5]
l2 =[i*22 for i in l1]

# %%
l2
# Out:
# [22, 44, 66, 88, 110]

# %%
import numpy as np
df = df.replace({np.nan: None})

# %%
tuples = [tuple(x) for x in df.to_numpy()]

# %%
tuples
# Out:
# [(74579,
#   77,
#   'Female',
#   'Emergency',
#   'Stroke',
#   'Hypertension',
#   0.0,
#   '126/76',
#   75,
#   'None',
#   'Mild',
#   'Medicare',
#   'Upper class',
#   100,
#   'Ward',
#   'Rehabilitation facility',
#   42),
#  (70994,
#   41,
#   'Male',
#   'Urgent',
#   'Fracture',
#   'None',
#   7.0,
#   '167/99',
#   69,
#   'Hip Replacement',
#   'Severe',
#   'Medicaid',
#   'Upper class',
#   500,
#   'Semiprivate',
#   'Deceased',
#   40),
#  (58228,
#   23,
#   'Other',
#   'Newborn',
#   'Heart Attack',
#   'Obesity',
#   5.0,
#   '106/70',
#   69,
#   'None',
#   'Critical',
#   'Medicare',
#   'Below poverty line',
#   100,
#   'Semiprivate',
#   'Deceased',
#   41),
#  (44881,
#   31,
#   'Female',
#   'Newborn',
#   'Heart Attack',
#   'Chronic Kidney Disease',
#   8.0,
#   '115/99',
#   97,
#   'Hip Replacement',
#   'Mild',
#   'Medicare',
#   'Lower class',
#   300,
#   'Semiprivate',
#   'Longterm care facility',
#   18),
#  (84716,
#   69,
#   'Other',
# ...

# %%
from psycopg2.extras import execute_values
insert_query ="""INSERT INTO length_of_stay5(Patient_ID, Age, Gender, Admission_Type, Primary_Diagnosis,
       Comorbidities, Previous_Hospitalizations, BP, Heart_rate,
       Surgical_Procedures, Severity_of_Illness, Insurance_Type,
       Socioeconomic_Status, Hospital_Total_Beds, Room_Type,
       Discharge_Destination, Length_of_Stay_in_days) VALUES %s"""

try:
  conn = psycopg2.connect(DATABASE_URL)
  cursor = conn.cursor()
  execute_values(cursor, insert_query, tuples)
  conn.commit()
  cursor.close()
  conn.close()
except Exception as e:
    print(e)

# %%
query1 = """ SELECT * FROM length_of_stay5"""

# %%
try:
  conn = psycopg2.connect(DATABASE_URL)
  cursor = conn.cursor()
  cursor.execute(query1)
  result = cursor.fetchall()
  cursor.close()
  conn.close()
except Exception as e:
    print(e)

# %%
df1
# Out:
#      Patient_ID  Age  Gender Admission_Type Primary_Diagnosis  \
# 0         74579   77  Female      Emergency            Stroke
# 1         70994   41    Male         Urgent          Fracture
# 2         58228   23   Other        Newborn      Heart Attack
# 3         44881   31  Female        Newborn      Heart Attack
# 4         84716   69   Other         Urgent          Fracture
# ..          ...  ...     ...            ...               ...
# 995       12035   35  Female       Elective          Diabetes
# 996       57742   28   Other      Emergency      Heart Attack
# 997       89928   98   Other        Newborn         Pneumonia
# 998       99495    7    Male      Emergency         Pneumonia
# 999       67395    8    Male       Elective         Pneumonia
#
#               Comorbidities  Previous_Hospitalizations      BP  Heart_rate  \
# 0              Hypertension                        0.0  126/76          75
# ...

# %%
query2 = """ SELECT * FROM length_of_stay5 WHERE Patient_ID = 1"""

# %%
try:
  conn = psycopg2.connect(DATABASE_URL)
  cursor = conn.cursor()
  cursor.execute(query2)
  result = cursor.fetchall()
  df2 = pd.DataFrame(result,columns=["name","diagnosis",'prescription','patient_id'])
  cursor.close()
  conn.close()
except Exception as e:
    print(e)

# %%
df2
# Out:
# Empty DataFrame
# Columns: [name, diagnosis, prescription, patient_id]
# Index: []

# %%
query3 = """ SELECT * FROM length_of_stay5 WHERE age > 50  """

# %%
try:
  conn = psycopg2.connect(DATABASE_URL)
  cursor = conn.cursor()
  cursor.execute(query3)
  rows = cursor.fetchall()
  df3 = pd.DataFrame(rows,columns=df.columns)
  cursor.close()
  conn.close()
except Exception as e:
    print(e)

# %%
df3
# Out:
#      Patient_ID  Age  Gender Admission_Type Primary_Diagnosis  \
# 0         74579   77  Female      Emergency            Stroke
# 1         84716   69   Other         Urgent          Fracture
# 2         74689   57    Male      Emergency      Heart Attack
# 3         78605   77  Female        Newborn          Diabetes
# 4         45730   59  Female         Urgent            Stroke
# ..          ...  ...     ...            ...               ...
# 474       28452   82  Female         Urgent         Pneumonia
# 475       83986   63    Male       Elective         Pneumonia
# 476       98583   55   Other      Emergency          Fracture
# 477       80429   93  Female        Newborn          Fracture
# 478       89928   98   Other        Newborn         Pneumonia
#
#               Comorbidities  Previous_Hospitalizations      BP Heart_rate  \
# 0              Hypertension                        0.0  126/76         75
# ...

# %%
query4 = """ SELECT gender,avg(age) FROM length_of_stay5 GROUP BY  gender """

# %%
try:
  conn = psycopg2.connect(DATABASE_URL)
  cursor = conn.cursor()
  cursor.execute(query4)
  rows = cursor.fetchall()
  df4 = pd.DataFrame(rows,columns=["gender","avg_age"])
  cursor.close()
  conn.close()
except Exception as e:
    print(e)

# %%
df4
# Out:
#    gender              avg_age
# 0   Other  46.9392971246006390
# 1    Male  52.3373493975903614
# 2  Female  47.9352112676056338

# %%
query5 = """SELECT gender, SUM(age) FROM PatientDetails GROUP BY gender HAVING SUM(age) < 40;"""
try:
  conn = psycopg2.connect(DATABASE_URL)
  cursor = conn.cursor()

  cursor.execute(query5)
  result = cursor.fetchall()
  df = pd.DataFrame(result, columns=(["gender", "sum_age"]))
  conn.commit()
  cursor.close()
  conn.close()

except Exception as e:
    print(e)

# %%
query6 = """UPDATE length_of_stay5 SET gender = 'male' WHERE patient_ID = 59213"""

# %%
try:
  conn = psycopg2.connect(DATABASE_URL)
  cursor = conn.cursor()
  cursor.execute(query6)
  conn.commit()
  cursor.close()
  conn.close()
  print("Updated successfully")
except Exception as e:
    print(e)
# Out:
# Updated successfully

# %%
query7 ="""
CREATE TABLE your_table_sample AS TABLE length_of_stay5;
"""

# %%
try:
  conn = psycopg2.connect(DATABASE_URL)
  cursor = conn.cursor()
  cursor.execute(query7)
  conn.commit()
  cursor.close()
  conn.close()
  print("query executed successfully")
except Exception as e:
    print(e)
# Out:
# query executed successfully

# %%
query8 ="""
DROP TABLE IF EXISTS your_table_sample;
"""

# %%
try:
  conn = psycopg2.connect(DATABASE_URL)
  cursor = conn.cursor()
  cursor.execute(query8)
  conn.commit()
  cursor.close()
  conn.close()
  print("Query executed successfully")
except Exception as e:
    print(e)
# Out:
# Query executed successfully

# %%
create_table_query = """CREATE TABLE IF NOT EXISTS length_of_stay5_constraint (
  patient_id integer PRIMARY KEY,
  age integer check (age>=0),
  gender text check (gender in ('male','female','other')),
  admission_type text not null,
  admission_type text,
  primary_diagnosis text,
  comorbidities text,
