# %% [markdown]
# <a href="https://colab.research.google.com/github/Navathamarkeeri/PROJECT/blob/ML/time_series_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install fb prophet

# %%
import pandas as pd
from prophet import Prophet

# %%
df =pd.read_csv('//content/Hospital_Finance.csv')

# %%
df.columns
# Out:
# Index(['Hospital ID', 'Date', 'Revenue', 'Expenses'], dtype='object')

# %%
df = df.tail(60)

# %%
df['Date']= pd.to_datetime(df['Date'],format='%d-%m-%Y')

# %%
ts_data_edit = df[['Date','Revenue']]
ts_data_edit.rename(columns={'Date':'ds','Revenue':'y'},inplace=True)
model = Prophet() # Now Prophet is defined
model.fit(ts_data_edit)

future = model.make_future_dataframe(periods=30)
forecast = model.predict(future)

from prophet.plot import add_changepoints_to_plot
import matplotlib.pyplot as plt
fig = model.plot(forecast)
# Out:
# <ipython-input-26-23e3be81bc59>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ts_data_edit.rename(columns={'Date':'ds','Revenue':'y'},inplace=True)
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnmlucoq1/sgt9pw8z.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnmlucoq1/cpahiwjm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# ...

# %%
ts_data_edit = df[['Date','Expenses']]
ts_data_edit.rename(columns={'Date':'ds','Expenses':'y'},inplace=True)
model = Prophet() # Now Prophet is defined
model.fit(ts_data_edit)

future = model.make_future_dataframe(periods=30)
forecast = model.predict(future)

from prophet.plot import add_changepoints_to_plot
import matplotlib.pyplot as plt
fig = model.plot(forecast)
# Out:
# <ipython-input-28-7877d16fc682>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ts_data_edit.rename(columns={'Date':'ds','Expenses':'y'},inplace=True)
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnmlucoq1/7jpjhi1v.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpnmlucoq1/u3px7lcs.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# ...
